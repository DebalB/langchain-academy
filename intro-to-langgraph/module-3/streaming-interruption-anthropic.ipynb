# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/langchain-ai/langchain-academy/blob/main/module-3/streaming-interruption.ipynb) [![Open in LangChain Academy](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66e9eba12c7b7688aa3dbb5e_LCA-badge-green.svg)](https://academy.langchain.com/courses/take/intro-to-langgraph/lessons/58239464-lesson-1-streaming)

# %% [markdown]
# # Streaming
#
# ## Review
#
# In module 2, covered a few ways to customize graph state and memory.
#
# We built up to a Chatbot with external memory that can sustain long-running conversations.
#
# ## Goals
#
# This module will dive into `human-in-the-loop`, which builds on memory and allows users to interact directly with graphs in various ways.
#
# To set the stage for `human-in-the-loop`, we'll first dive into streaming, which provides several ways to visualize graph output (e.g., node state or chat model tokens) over the course of execution.

# %%
# %%capture --no-stderr
# %pip install --quiet -U langgraph langchain_anthropic langgraph_sdk
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Streaming
#
# LangGraph is built with [first class support for streaming](https://langchain-ai.github.io/langgraph/concepts/low_level/#streaming).
#
# Let's set up our Chatbot from Module 2, and show various way to stream outputs from the graph during execution.

# %%
import os, getpass

def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

_set_env("ANTHROPIC_API_KEY")

# %% [markdown]
# Note that we use `RunnableConfig` with `call_model` to enable token-wise streaming. This is [only needed with python < 3.11](https://langchain-ai.github.io/langgraph/how-tos/streaming-tokens/). We include in case you are running this notebook in CoLab, which will use python 3.x.

# %%
from IPython.display import Image, display

from langchain_anthropic import ChatAnthropic
from langchain_core.messages import SystemMessage, HumanMessage, RemoveMessage
from langchain_core.runnables import RunnableConfig

from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import StateGraph, START, END
from langgraph.graph import MessagesState

# LLM
model = ChatAnthropic(model="claude-3-5-sonnet-20241022",temperature=0)

# State 
class State(MessagesState):
    summary: str

# Define the logic to call the model
def call_model(state: State, config: RunnableConfig):
    
    # Get summary if it exists
    summary = state.get("summary", "")

    # If there is summary, then we add it
    if summary:
        
        # Add summary to system message
        system_message = f"Summary of conversation earlier: {summary}"

        # Append summary to any newer messages
        messages = [SystemMessage(content=system_message)] + state["messages"]
    
    else:
        messages = state["messages"]
    
    response = model.invoke(messages, config)
    return {"messages": response}

def summarize_conversation(state: State):
    
    # First, we get any existing summary
    summary = state.get("summary", "")

    # Create our summarization prompt 
    if summary:
        
        # A summary already exists
        summary_message = (
            f"This is summary of the conversation to date: {summary}\n\n"
            "Extend the summary by taking into account the new messages above:"
        )
        
    else:
        summary_message = "Create a summary of the conversation above:"

    # Add prompt to our history
    messages = state["messages"] + [HumanMessage(content=summary_message)]
    response = model.invoke(messages)
    
    # Delete all but the 2 most recent messages
    delete_messages = [RemoveMessage(id=m.id) for m in state["messages"][:-2]]
    return {"summary": response.content, "messages": delete_messages}

# Determine whether to end or summarize the conversation
def should_continue(state: State):
    
    """Return the next node to execute."""
    
    messages = state["messages"]
    
    # If there are more than six messages, then we summarize the conversation
    if len(messages) > 6:
        return "summarize_conversation"
    
    # Otherwise we can just end
    return END

# Define a new graph
workflow = StateGraph(State)
workflow.add_node("conversation", call_model)
workflow.add_node(summarize_conversation)

# Set the entrypoint as conversation
workflow.add_edge(START, "conversation")
workflow.add_conditional_edges("conversation", should_continue)
workflow.add_edge("summarize_conversation", END)

# Compile
memory = MemorySaver()
graph = workflow.compile(checkpointer=memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ### Streaming full state
#
# Now, let's talk about ways to [stream our graph state](https://langchain-ai.github.io/langgraph/concepts/low_level/#streaming).
#
# `.stream` and `.astream` are sync and async methods for streaming back results.
#
# LangGraph supports a few [different streaming modes](https://langchain-ai.github.io/langgraph/how-tos/stream-values/) for [graph state](https://langchain-ai.github.io/langgraph/how-tos/stream-values/):
#
# * `values`: This streams the full state of the graph after each node is called.
# * `updates`: This streams updates to the state of the graph after each node is called.
#
# ![values_vs_updates.png](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66dbaf892d24625a201744e5_streaming1.png)
#
# Let's look at `stream_mode="updates"`.
#
# Because we stream with `updates`, we only see updates to the state after node in the graph is run.
#
# Each `chunk` is a dict with `node_name` as the key and the updated state as the value.

# %%
# Create a thread
config = {"configurable": {"thread_id": "1"}}

# Start conversation
for chunk in graph.stream({"messages": [HumanMessage(content="hi! I'm Lance")]}, config, stream_mode="updates"):
    print(chunk)
# Out:
# {'conversation': {'messages': AIMessage(content="Hi Lance! I'm Claude. Nice to meet you! How can I help you today?", additional_kwargs={}, response_metadata={'id': 'msg_01KqEGvBGibUGa61UbfNw843', 'model': 'claude-3-5-sonnet-20241022', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 12, 'output_tokens': 22, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-3-5-sonnet-20241022'}, id='run--5a5bb30f-225d-4758-83f1-a86b42ffac7a-0', usage_metadata={'input_tokens': 12, 'output_tokens': 22, 'total_tokens': 34, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}})}}
# Failed to get info from https://api.smith.langchain.com: LangSmithConnectionError('Connection error caused failure to GET /info in LangSmith API. Please confirm your internet connection. ConnectTimeout(MaxRetryError("HTTPSConnectionPool(host=\'api.smith.langchain.com\', port=443): Max retries exceeded with url: /info (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000002471BEFDD10>, \'Connection to api.smith.langchain.com timed out. (connect timeout=10.0)\'))"))\nContent-Length: None\nAPI Key: lsv2_********************************************7a')
# Failed to batch ingest runs: langsmith.utils.LangSmithConnectionError: Connection error caused failure to POST https://api.smith.langchain.com/runs/batch in LangSmith API. Please confirm your internet connection. ConnectTimeout(MaxRetryError("HTTPSConnectionPool(host='api.smith.langchain.com', port=443): Max retries exceeded with url: /runs/batch (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000024734A336D0>, 'Connection to api.smith.langchain.com timed out. (connect timeout=10.0)'))"))
# Content-Length: 76707
# API Key: lsv2_********************************************7a
# post: trace=bee14334-a50a-427c-9b2d-6a57f4e5ca62,id=bee14334-a50a-427c-9b2d-6a57f4e5ca62; trace=bee14334-a50a-427c-9b2d-6a57f4e5ca62,id=c73f09dc-7861-415d-8126-7ebc0e3f1a33; trace=bee14334-a50a-427c-9b2d-6a57f4e5ca62,id=5a5bb30f-225d-4758-83f1-a86b42ffac7a; trace=bee14334-a50a-427c-9b2d-6a57f4e5ca62,id=2e02aec8-4db3-476d-99ef-d3c4352fcac6; trace=0a90541b-c06f-49ea-9aa0-2def4e6432a5,id=0a90541b-c06f-49ea-9aa0-2def4e6432a5; trace=0a90541b-c06f-49ea-9aa0-2def4e6432a5,id=2c31c7f8-48e8-4b2e-bbef-69dad3e478fd; trace=0a90541b-c06f-49ea-9aa0-2def4e6432a5,id=b63f1d08-2262-4fe3-b1ce-e86e1555d859; trace=0a90541b-c06f-49ea-9aa0-2def4e6432a5,id=70ca14a3-2577-493c-9b0a-aa44364d9955; trace=bb4abbb1-b878-4e43-839f-f70381f5956e,id=bb4abbb1-b878-4e43-839f-f70381f5956e; trace=bb4abbb1-b878-4e43-839f-f70381f5956e,id=3543373e-561e-4bd6-837e-db01c8cc7017; trace=bb4abbb1-b878-4e43-839f-f70381f5956e,id=59e46a94-cc1a-46c3-b0ea-8d0528550a98; trace=bb4abbb1-b878-4e43-839f-f70381f5956e,id=b9af1771-517f-4c4c-affc-b997df3af071; trace=290dcfff-b987-41e0-96c9-f99c670db0fb,id=290dcfff-b987-41e0-96c9-f99c670db0fb; trace=290dcfff-b987-41e0-96c9-f99c670db0fb,id=4a0a0570-5810-4267-a5a8-4ad10eb4518a; trace=290dcfff-b987-41e0-96c9-f99c670db0fb,id=f075cbd5-f840-4771-9e24-b12e8e7c03fb; trace=290dcfff-b987-41e0-96c9-f99c670db0fb,id=7eadba0f-157d-4948-be9e-9ede8e035df7; trace=05bce503-3616-421a-8cf7-1d05430832fe,id=05bce503-3616-421a-8cf7-1d05430832fe; trace=05bce503-3616-421a-8cf7-1d05430832fe,id=5842900b-9f27-4c41-9267-990b0d989ff6; trace=05bce503-3616-421a-8cf7-1d05430832fe,id=6399a0ba-1c92-4927-adf5-1228a4ad64b2; trace=05bce503-3616-421a-8cf7-1d05430832fe,id=9b8d4869-e9a9-41c6-b630-911d4293ed55; trace=42649c6e-77ca-488f-a2a8-64a13c07af25,id=42649c6e-77ca-488f-a2a8-64a13c07af25; trace=42649c6e-77ca-488f-a2a8-64a13c07af25,id=12dd1640-fe8c-4f42-825b-44a634d7f9e1; trace=42649c6e-77ca-488f-a2a8-64a13c07af25,id=6592bf2e-2f81-4e37-8a18-50a3e6175b66; trace=42649c6e-77ca-488f-a2a8-64a13c07af25,id=b4088fdb-569f-4f40-91e7-82b50a2bf589

# %% [markdown]
# Let's now just print the state update.

# %%
# Start conversation
for chunk in graph.stream({"messages": [HumanMessage(content="hi! I'm Lance")]}, config, stream_mode="updates"):
    chunk['conversation']["messages"].pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Hi Lance! You already introduced yourself, but that's okay. I'm Claude, an AI assistant. Is there anything in particular you'd like to chat about or any way I can help you today?

# %% [markdown]
# Now, we can see `stream_mode="values"`.
#
# This is the `full state` of the graph after the `conversation` node is called.

# %%
# Start conversation, again
config = {"configurable": {"thread_id": "2"}}

# Start conversation
input_message = HumanMessage(content="hi! I'm Lance")
for event in graph.stream({"messages": [input_message]}, config, stream_mode="values"):
    for m in event['messages']:
        m.pretty_print()
    print("---"*25)
# Out:
# ================================ Human Message =================================
#
# hi! I'm Lance
# ---------------------------------------------------------------------------
# ================================ Human Message =================================
#
# hi! I'm Lance
# ================================== Ai Message ==================================
#
# Hi Lance! I'm Claude. Nice to meet you! How can I help you today?
# ---------------------------------------------------------------------------

# %% [markdown]
# ### Streaming tokens
#
# We often want to stream more than graph state.
#
# In particular, with chat model calls it is common to stream the tokens as they are generated.
#
# We can do this [using the `.astream_events` method](https://langchain-ai.github.io/langgraph/how-tos/streaming-from-final-node/#stream-outputs-from-the-final-node), which streams back events as they happen inside nodes!
#
# Each event is a dict with a few keys:
#
# * `event`: This is the type of event that is being emitted.
# * `name`: This is the name of event.
# * `data`: This is the data associated with the event.
# * `metadata`: Contains`langgraph_node`, the node emitting the event.
#
# Let's have a look.

# %%
config = {"configurable": {"thread_id": "3"}}
input_message = HumanMessage(content="Tell me about the 49ers NFL team")
async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    print(f"Node: {event['metadata'].get('langgraph_node','')}. Type: {event['event']}. Name: {event['name']}")
# Out:
# Node: . Type: on_chain_start. Name: LangGraph
# Node: conversation. Type: on_chain_start. Name: conversation
# Node: conversation. Type: on_chat_model_start. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_stream. Name: ChatAnthropic
# Node: conversation. Type: on_chat_model_end. Name: ChatAnthropic
# Node: conversation. Type: on_chain_start. Name: should_continue
# Node: conversation. Type: on_chain_end. Name: should_continue
# Node: conversation. Type: on_chain_stream. Name: conversation
# Node: conversation. Type: on_chain_end. Name: conversation
# Node: . Type: on_chain_stream. Name: LangGraph
# Node: . Type: on_chain_end. Name: LangGraph

# %% [markdown]
# The central point is that tokens from chat models within your graph have the `on_chat_model_stream` type.
#
# We can use `event['metadata']['langgraph_node']` to select the node to stream from.
#
# And we can use `event['data']` to get the actual data for each event, which in this case is an `AIMessageChunk`.

# %%
node_to_stream = 'conversation'
config = {"configurable": {"thread_id": "4"}}
input_message = HumanMessage(content="Tell me about the 49ers NFL team")
async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    # Get chat model tokens from a particular node 
    if event["event"] == "on_chat_model_stream" and event['metadata'].get('langgraph_node','') == node_to_stream:
        print(event["data"])
# Out:
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'model_name': 'claude-3-5-sonnet-20241022'}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2', usage_metadata={'input_tokens': 16, 'output_tokens': 0, 'total_tokens': 16, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}})}
# {'chunk': AIMessageChunk(content='The San Francisco 49', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='ers are a professional American', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' football team based in the', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' San Francisco Bay Area (', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='they', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' currently', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' play their', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' home games at', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=" Levi's Stadium", additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' in Santa Clara, California', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='). They', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' are members', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' of the N', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='FC West division in the', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' National Football League (NFL', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=').\n\nKey', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' points about the 49', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='ers:\n\n1.', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' History:', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='\n-', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' Founded in 1946', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' as a', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' member', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' of the All-America', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' Football Conference', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='\n- Joined the NFL', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' in 1950', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='\n- Name', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='d after the prosp', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='ectors who came', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' to California during the ', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='1849 Gold Rush', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='\n\n2. Championships', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=':\n- Won', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' 5 Super', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' Bowl championships', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' (XVI', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=', XIX, XX', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='III, XXIV', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' XXIX)\n-', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' Won', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' 7', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' NFC Championships', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='\n- Multiple', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' division', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' titles', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='\n\n3. Notable', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' Players', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=':\n- Joe Montana', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='QB', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=')\n- Jerry Rice', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' (WR)', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='\n- Steve Young (QB', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=')\n- Ron', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='nie Lott (', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='DB', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=')\n- Roger', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' Craig (RB)', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='\n-', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' Dwight Clark (W', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='R)\n\n4.', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' Team', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' Colors:\n-', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' Scar', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='let Re', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='d an', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='d Metal', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='lic Gold\n\n5.', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' Notable', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' Achievements', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=':\n- Known', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' for the', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' "West', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' Coast Offense" under', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' Bill', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' Walsh\n- "', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='The', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' Catch" -', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' Famous', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' play between', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' Joe Montana and Dw', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='ight Clark (', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='1982)\n-', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' One', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' of the most successful franch', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='ises in NFL history', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='\n\n6. Recent', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' Stars', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=':\n- George', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' Kittle (', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='TE)\n- Nick', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' Bosa (DE', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=')\n-', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' Deebo Samuel (W', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='R)', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='\n- Christian', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' McCaffrey (R', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='B)\n\nThe', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' team', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' has maintaine', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='d a strong following', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' an', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='d continues', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' to be one of the', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' NFL', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content="'s most popular", additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content=' an', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='d successful franchises.', additional_kwargs={}, response_metadata={}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2')}
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'stop_reason': 'end_turn', 'stop_sequence': None}, id='run--6399a0ba-1c92-4927-adf5-1228a4ad64b2', usage_metadata={'input_tokens': 0, 'output_tokens': 362, 'total_tokens': 362})}

# %% [markdown]
# As you see above, just use the `chunk` key to get the `AIMessageChunk`.

# %%
config = {"configurable": {"thread_id": "5"}}
input_message = HumanMessage(content="Tell me about the 49ers NFL team")
async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    # Get chat model tokens from a particular node 
    if event["event"] == "on_chat_model_stream" and event['metadata'].get('langgraph_node','') == node_to_stream:
        data = event["data"]
        print(data["chunk"].content, end="|")
# Out:
# |The San Francisco 49|ers are a professional American| football team based in the| San Francisco Bay Area (|they| currently| play their| home games at| Levi's Stadium| in Santa Clara, California|). They| are members| of the N|FC West division in the| National Football League (NFL|).
#
# Key| points about the 49|ers:
#
# 1.| History:|
# -| Founded in 1946| as a| member| of the All-America| Football Conference|
# - Joined the NFL| in 1950|
# - Name|d after the prosp|ectors who came| to California during the |1849 Gold Rush|
#
# 2. Championships|:
# - Won| 5 Super| Bowl championships| (XVI|, XIX, XX|III, XXIV|,| XXIX)
# -| Won| 7| NFC Championships|
# - Multiple| division| titles|
#
# 3. Notable| Players|:
# - Joe Montana| (|QB|)
# - Jerry Rice| (WR)|
# - Steve Young (QB|)
# - Ron|nie Lott (|DB|)
# - Roger| Craig (RB)|
# -| Dwight Clark (W|R)
#
# 4.| Team| Colors:
# - Re|d an|d Gol|d
#
# 5. Notable| Achievements|:
# - Known| for the| "West| Coast Offense" under| Bill| Walsh
# - "|The| Catch" -| Famous| play in| 1982 N|FC Championship game|
# - One| of the most successful franch|ises in NFL history|
#
# 6. Recent| Stars|:
# - George| Kittle (|TE)
# - Nick| Bosa (DE|)
# -| Deebo Samuel (W|R)|
# - Christian| McCaffrey (R|B)
#
# The| team| has maintaine|d a strong following| an|d continues| to be one of the| NFL|'s most popular| an|d successful franchises.||

# %% [markdown]
# ### Streaming with LangGraph API
#
# **⚠️ DISCLAIMER**
#
# Since the filming of these videos, we've updated Studio so that it can be run locally and opened in your browser. This is now the preferred way to run Studio (rather than using the Desktop App as shown in the video). See documentation [here](https://langchain-ai.github.io/langgraph/concepts/langgraph_studio/#local-development-server) on the local development server and [here](https://langchain-ai.github.io/langgraph/how-tos/local-studio/#run-the-development-server). To start the local development server, run the following command in your terminal in the `/studio` directory in this module:
#
# ```
# langgraph dev
# ```
#
# You should see the following output:
# ```
# - 🚀 API: http://127.0.0.1:2024
# - 🎨 Studio UI: https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024
# - 📚 API Docs: http://127.0.0.1:2024/docs
# ```
#
# Open your browser and navigate to the Studio UI: `https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024`.
#
# The LangGraph API [supports editing graph state](https://langchain-ai.github.io/langgraph/cloud/how-tos/human_in_the_loop_edit_state/#initial-invocation).

# %%
if 'google.colab' in str(get_ipython()):
    raise Exception("Unfortunately LangGraph Studio is currently not supported on Google Colab")

# %%
from langgraph_sdk import get_client

# This is the URL of the local development server
URL = "http://127.0.0.1:2024"
client = get_client(url=URL)

# Search all hosted graphs
assistants = await client.assistants.search()

# %%
assistants
# Out:
# [{'assistant_id': '1747cff5-24f7-5a68-b440-2a69c5ef1f69',
#   'graph_id': 'agent-anthropic',
#   'config': {},
#   'metadata': {'created_by': 'system'},
#   'name': 'agent-anthropic',
#   'created_at': '2025-07-02T09:57:59.397458+00:00',
#   'updated_at': '2025-07-02T09:57:59.397458+00:00',
#   'version': 1,
#   'description': None},
#  {'assistant_id': 'fe096781-5601-53d2-b2f6-0d3403f7e9ca',
#   'graph_id': 'agent',
#   'config': {},
#   'metadata': {'created_by': 'system'},
#   'name': 'agent',
#   'created_at': '2025-06-28T11:57:57.412181+00:00',
#   'updated_at': '2025-06-28T11:57:57.412181+00:00',
#   'version': 1,
#   'description': None},
#  {'assistant_id': '228f9934-0cdd-5383-92c8-ee8422522cc2',
#   'graph_id': 'router',
#   'config': {},
#   'metadata': {'created_by': 'system'},
#   'name': 'router',
#   'created_at': '2025-06-28T11:57:57.392159+00:00',
#   'updated_at': '2025-06-28T11:57:57.392159+00:00',
#   'version': 1,
#   'description': None},
#  {'assistant_id': '28d99cab-ad6c-5342-aee5-400bd8dc9b8b',
#   'graph_id': 'simple_graph',
#   'config': {},
#   'metadata': {'created_by': 'system'},
#   'name': 'simple_graph',
#   'created_at': '2025-06-28T11:57:55.102826+00:00',
#   'updated_at': '2025-06-28T11:57:55.102826+00:00',
#   'version': 1,
#   'description': None}]

# %% [markdown]
# Let's [stream `values`](https://langchain-ai.github.io/langgraph/cloud/how-tos/stream_values/), like before.

# %%
# Create a new thread
thread = await client.threads.create()
# Input message
input_message = HumanMessage(content="Multiply 2 and 3")
async for event in client.runs.stream(thread["thread_id"], 
                                      assistant_id="agent-anthropic", 
                                      input={"messages": [input_message]}, 
                                      stream_mode="values"):
    print(event)
# Out:
# StreamPart(event='metadata', data={'run_id': '1f057fa0-6276-6d03-980b-5d314664ab7d', 'attempt': 1})
# StreamPart(event='values', data={'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '3e2a51b0-9ed0-4c7e-92a5-915d2cd4f1ad', 'example': False}]})
# StreamPart(event='values', data={'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '3e2a51b0-9ed0-4c7e-92a5-915d2cd4f1ad', 'example': False}, {'content': [{'text': "I'll help you multiply 2 and 3 using the multiply function.", 'type': 'text'}, {'id': 'toolu_01PMtCeVoasfkRPZri9FRcGV', 'input': {'a': 2, 'b': 3}, 'name': 'multiply', 'type': 'tool_use'}], 'additional_kwargs': {}, 'response_metadata': {'id': 'msg_01P7bpqGVuX4BJfWRjbv5qJv', 'model': 'claude-3-5-sonnet-20241022', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 581, 'output_tokens': 86, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-3-5-sonnet-20241022'}, 'type': 'ai', 'name': None, 'id': 'run--2043289d-f73c-403f-95cb-3715d046202e-0', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'toolu_01PMtCeVoasfkRPZri9FRcGV', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 581, 'output_tokens': 86, 'total_tokens': 667, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}}}]})
# StreamPart(event='values', data={'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '3e2a51b0-9ed0-4c7e-92a5-915d2cd4f1ad', 'example': False}, {'content': [{'text': "I'll help you multiply 2 and 3 using the multiply function.", 'type': 'text'}, {'id': 'toolu_01PMtCeVoasfkRPZri9FRcGV', 'input': {'a': 2, 'b': 3}, 'name': 'multiply', 'type': 'tool_use'}], 'additional_kwargs': {}, 'response_metadata': {'id': 'msg_01P7bpqGVuX4BJfWRjbv5qJv', 'model': 'claude-3-5-sonnet-20241022', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 581, 'output_tokens': 86, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-3-5-sonnet-20241022'}, 'type': 'ai', 'name': None, 'id': 'run--2043289d-f73c-403f-95cb-3715d046202e-0', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'toolu_01PMtCeVoasfkRPZri9FRcGV', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 581, 'output_tokens': 86, 'total_tokens': 667, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}}}, {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': 'aeabd494-c320-44da-b918-978e1650b2ff', 'tool_call_id': 'toolu_01PMtCeVoasfkRPZri9FRcGV', 'artifact': None, 'status': 'success'}]})
# StreamPart(event='', data=None)
# StreamPart(event='values', data={'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '3e2a51b0-9ed0-4c7e-92a5-915d2cd4f1ad', 'example': False}, {'content': [{'text': "I'll help you multiply 2 and 3 using the multiply function.", 'type': 'text'}, {'id': 'toolu_01PMtCeVoasfkRPZri9FRcGV', 'input': {'a': 2, 'b': 3}, 'name': 'multiply', 'type': 'tool_use'}], 'additional_kwargs': {}, 'response_metadata': {'id': 'msg_01P7bpqGVuX4BJfWRjbv5qJv', 'model': 'claude-3-5-sonnet-20241022', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 581, 'output_tokens': 86, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-3-5-sonnet-20241022'}, 'type': 'ai', 'name': None, 'id': 'run--2043289d-f73c-403f-95cb-3715d046202e-0', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'toolu_01PMtCeVoasfkRPZri9FRcGV', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 581, 'output_tokens': 86, 'total_tokens': 667, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}}}, {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': 'aeabd494-c320-44da-b918-978e1650b2ff', 'tool_call_id': 'toolu_01PMtCeVoasfkRPZri9FRcGV', 'artifact': None, 'status': 'success'}, {'content': 'The result of multiplying 2 and 3 is 6.', 'additional_kwargs': {}, 'response_metadata': {'id': 'msg_013QD9sKK69SmBwUtZm3uYmD', 'model': 'claude-3-5-sonnet-20241022', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 679, 'output_tokens': 20, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-3-5-sonnet-20241022'}, 'type': 'ai', 'name': None, 'id': 'run--56f11bde-e95f-430f-b5f3-58a9b5272476-0', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 679, 'output_tokens': 20, 'total_tokens': 699, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}}}]})

# %% [markdown]
# The streamed objects have:
#
# * `event`: Type
# * `data`: State

# %%
from langchain_core.messages import convert_to_messages
thread = await client.threads.create()
input_message = HumanMessage(content="Multiply 2 and 3")
async for event in client.runs.stream(thread["thread_id"], assistant_id="agent-anthropic", input={"messages": [input_message]}, stream_mode="values"):
    if event:
        messages = event.data.get('messages',None)
        if messages:
            print(convert_to_messages(messages)[-1])
        print('='*25)
# Out:
# =========================
# content='Multiply 2 and 3' additional_kwargs={} response_metadata={} id='8a0a67af-11ad-4c15-8f79-e8cee61fc74c'
# =========================
# content=[{'text': "I'll help you multiply 2 and 3 using the multiply function.", 'type': 'text'}, {'id': 'toolu_01Fut7RJmc7njsY6SJPoQNdo', 'input': {'a': 2, 'b': 3}, 'name': 'multiply', 'type': 'tool_use'}] additional_kwargs={'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 581, 'output_tokens': 86, 'total_tokens': 667, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}}} response_metadata={'id': 'msg_01WjW9kK6skwPzsidbnvH4cm', 'model': 'claude-3-5-sonnet-20241022', 'stop_reason': 'tool_use', 'stop_sequence': None, 'usage': {'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 581, 'output_tokens': 86, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-3-5-sonnet-20241022'} id='run--0f30384b-9a06-4312-8d61-1240abcf6f76-0' tool_calls=[{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'toolu_01Fut7RJmc7njsY6SJPoQNdo', 'type': 'tool_call'}]
# =========================
# content='6' name='multiply' id='374adaa6-51c5-45fe-92e8-4d3324bfec87' tool_call_id='toolu_01Fut7RJmc7njsY6SJPoQNdo'
# =========================
# content='The result of multiplying 2 and 3 is 6.' additional_kwargs={'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 679, 'output_tokens': 20, 'total_tokens': 699, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}}} response_metadata={'id': 'msg_01Myasz9Xzx9AgmYBZzEfrCr', 'model': 'claude-3-5-sonnet-20241022', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 679, 'output_tokens': 20, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-3-5-sonnet-20241022'} id='run--b6c5f2d9-67b4-4a8a-afb2-9aea3bb4a8fa-0'
# =========================

# %% [markdown]
# There are some new streaming mode that are only supported via the API.
#
# For example, we can [use `messages` mode](https://langchain-ai.github.io/langgraph/cloud/how-tos/stream_messages/) to better handle the above case!
#
# This mode currently assumes that you have a `messages` key in your graph, which is a list of messages.
#
# All events emitted using `messages` mode have two attributes:
#
# * `event`: This is the name of the event
# * `data`: This is data associated with the event

# %%
thread = await client.threads.create()
input_message = HumanMessage(content="Multiply 2 and 3")
async for event in client.runs.stream(thread["thread_id"], 
                                      assistant_id="agent-anthropic", 
                                      input={"messages": [input_message]}, 
                                      stream_mode="messages"):
    if event:
        print(event.event)
# Out:
# metadata
# messages/metadata
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/metadata
# messages/complete
# messages/metadata
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial

# %% [markdown]
# We can see a few events:
#
# * `metadata`: metadata about the run
# * `messages/complete`: fully formed message
# * `messages/partial`: chat model tokens
#
# You can dig further into the types [here](https://langchain-ai.github.io/langgraph/cloud/concepts/api/#modemessages).
#
# Now, let's show how to stream these messages.
#
# We'll define a helper function for better formatting of the tool calls in messages.

# %%
thread = await client.threads.create()
input_message = HumanMessage(content="Multiply 2 and 3")

def format_tool_calls(tool_calls):
    """
    Format a list of tool calls into a readable string.

    Args:
        tool_calls (list): A list of dictionaries, each representing a tool call.
            Each dictionary should have 'id', 'name', and 'args' keys.

    Returns:
        str: A formatted string of tool calls, or "No tool calls" if the list is empty.

    """

    if tool_calls:
        formatted_calls = []
        for call in tool_calls:
            formatted_calls.append(
                f"Tool Call ID: {call['id']}, Function: {call['name']}, Arguments: {call['args']}"
            )
        return "\n".join(formatted_calls)
    return "No tool calls"

async for event in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent-anthropic",
    input={"messages": [input_message]},
    stream_mode="messages",):
    
    # Handle metadata events
    if event.event == "metadata":
        print(f"Metadata: Run ID - {event.data['run_id']}")
        print("-" * 50)
    
    # Handle partial message events
    elif event.event == "messages/partial":
        for data_item in event.data:
            # Process user messages
            if "role" in data_item and data_item["role"] == "user":
                print(f"Human: {data_item['content']}")
            else:
                # Extract relevant data from the event
                tool_calls = data_item.get("tool_calls", [])
                invalid_tool_calls = data_item.get("invalid_tool_calls", [])
                content = data_item.get("content", "")
                response_metadata = data_item.get("response_metadata", {})

                if content:
                    print(f"AI: {content}")

                if tool_calls:
                    print("Tool Calls:")
                    print(format_tool_calls(tool_calls))

                if invalid_tool_calls:
                    print("Invalid Tool Calls:")
                    print(format_tool_calls(invalid_tool_calls))

                if response_metadata:
                    finish_reason = response_metadata.get("finish_reason", "N/A")
                    print(f"Response Metadata: Finish Reason - {finish_reason}")
                    
        print("-" * 50)
# Out:
# Metadata: Run ID - 1f057fa7-bf46-6044-a15c-dab0ee6b5bd5
# --------------------------------------------------
# Response Metadata: Finish Reason - N/A
# --------------------------------------------------
# AI: [{'text': 'I', 'type': 'text', 'index': 0}]
# Response Metadata: Finish Reason - N/A
# --------------------------------------------------
# AI: [{'text': "I'll", 'type': 'text', 'index': 0}]
# Response Metadata: Finish Reason - N/A
# --------------------------------------------------
# AI: [{'text': "I'll help", 'type': 'text', 'index': 0}]
# Response Metadata: Finish Reason - N/A
# --------------------------------------------------
# AI: [{'text': "I'll help you multiply 2 ", 'type': 'text', 'index': 0}]
# Response Metadata: Finish Reason - N/A
# --------------------------------------------------
# AI: [{'text': "I'll help you multiply 2 and 3 using", 'type': 'text', 'index': 0}]
# Response Metadata: Finish Reason - N/A
# --------------------------------------------------
# AI: [{'text': "I'll help you multiply 2 and 3 using the multiply", 'type': 'text', 'index': 0}]
# Response Metadata: Finish Reason - N/A
# --------------------------------------------------
# AI: [{'text': "I'll help you multiply 2 and 3 using the multiply function.", 'type': 'text', 'index': 0}]
# Response Metadata: Finish Reason - N/A
# --------------------------------------------------
# AI: [{'text': "I'll help you multiply 2 and 3 using the multiply function.", 'type': 'text', 'index': 0}, {'id': 'toolu_014uDt7uk4zhuxBvv25kGzof', 'input': {}, 'name': 'multiply', 'type': 'tool_use', 'index': 1}]
# Tool Calls:
# Tool Call ID: toolu_014uDt7uk4zhuxBvv25kGzof, Function: multiply, Arguments: {}
# Response Metadata: Finish Reason - N/A
# --------------------------------------------------
# AI: [{'text': "I'll help you multiply 2 and 3 using the multiply function.", 'type': 'text', 'index': 0}, {'id': 'toolu_014uDt7uk4zhuxBvv25kGzof', 'input': {}, 'name': 'multiply', 'type': 'tool_use', 'index': 1, 'partial_json': ''}]
# Tool Calls:
# Tool Call ID: toolu_014uDt7uk4zhuxBvv25kGzof, Function: multiply, Arguments: {}
# Response Metadata: Finish Reason - N/A
# --------------------------------------------------
# AI: [{'text': "I'll help you multiply 2 and 3 using the multiply function.", 'type': 'text', 'index': 0}, {'id': 'toolu_014uDt7uk4zhuxBvv25kGzof', 'input': {}, 'name': 'multiply', 'type': 'tool_use', 'index': 1, 'partial_json': '{"a": 2'}]
# Tool Calls:
# Tool Call ID: toolu_014uDt7uk4zhuxBvv25kGzof, Function: multiply, Arguments: {'a': 2}
# Response Metadata: Finish Reason - N/A
# --------------------------------------------------
# AI: [{'text': "I'll help you multiply 2 and 3 using the multiply function.", 'type': 'text', 'index': 0}, {'id': 'toolu_014uDt7uk4zhuxBvv25kGzof', 'input': {}, 'name': 'multiply', 'type': 'tool_use', 'index': 1, 'partial_json': '{"a": 2, "'}]
# Tool Calls:
# Tool Call ID: toolu_014uDt7uk4zhuxBvv25kGzof, Function: multiply, Arguments: {'a': 2}
# Response Metadata: Finish Reason - N/A
# --------------------------------------------------
# AI: [{'text': "I'll help you multiply 2 and 3 using the multiply function.", 'type': 'text', 'index': 0}, {'id': 'toolu_014uDt7uk4zhuxBvv25kGzof', 'input': {}, 'name': 'multiply', 'type': 'tool_use', 'index': 1, 'partial_json': '{"a": 2, "b": 3}'}]
# Tool Calls:
# Tool Call ID: toolu_014uDt7uk4zhuxBvv25kGzof, Function: multiply, Arguments: {'a': 2, 'b': 3}
# Response Metadata: Finish Reason - N/A
# --------------------------------------------------
# AI: [{'text': "I'll help you multiply 2 and 3 using the multiply function.", 'type': 'text', 'index': 0}, {'id': 'toolu_014uDt7uk4zhuxBvv25kGzof', 'input': {}, 'name': 'multiply', 'type': 'tool_use', 'index': 1, 'partial_json': '{"a": 2, "b": 3}'}]
# Tool Calls:
# Tool Call ID: toolu_014uDt7uk4zhuxBvv25kGzof, Function: multiply, Arguments: {'a': 2, 'b': 3}
# Response Metadata: Finish Reason - N/A
# --------------------------------------------------
# Response Metadata: Finish Reason - N/A
# --------------------------------------------------
# AI: [{'text': 'The result of multipl', 'type': 'text', 'index': 0}]
# Response Metadata: Finish Reason - N/A
# --------------------------------------------------
# AI: [{'text': 'The result of multiplying 2 an', 'type': 'text', 'index': 0}]
# Response Metadata: Finish Reason - N/A
# --------------------------------------------------
# AI: [{'text': 'The result of multiplying 2 and 3 is ', 'type': 'text', 'index': 0}]
# Response Metadata: Finish Reason - N/A
# --------------------------------------------------
# AI: [{'text': 'The result of multiplying 2 and 3 is 6.', 'type': 'text', 'index': 0}]
# Response Metadata: Finish Reason - N/A
# --------------------------------------------------
# AI: [{'text': 'The result of multiplying 2 and 3 is 6.', 'type': 'text', 'index': 0}]
# Response Metadata: Finish Reason - N/A
# --------------------------------------------------
